# %%
from pymorphy2 import MorphAnalyzer
import pandas as pd
import re
import string
from pprint import pprint

# %%
dfq = pd.read_csv("data/questions.csv", sep=';')
dfq.head()
# Out:
#   qnum                               question
# 0  1_1              Что нового будет в марте?
# 1  1_2       Когда приедет выставка Морозова?
# 2  1_3  Расскажи мне про Пятницы в Пушкинском
# 3  1_4         Когда откроется выставка Тату?
# 4  1_5              Цены на билеты Гейнсборо?

# %%
qlist = list(dfq["question"])
qt = qlist[0]

# %%
def lemm(text):
    # lowercase
    text = ' '.join(word.lower() for word in text.split())
    # убираем переносы строки и тд 
    text = re.sub("\-\s\r\n\s{1,}|\-\s\r\n|\r\n", '', text)
    # все спецсимволы меняем на пробел
    for chr in string.punctuation:
        text = text.replace(chr, ' ')
    # слово к нормлаьному виду
    text = ' '.join(MorphAnalyzer().parse(word)[0].normal_form for word in text.split())
    return text

# %%
dfq["lemmatization"] = dfq["question"].apply(lemm)
dfq
# Out:
#     qnum                                           question  \
# 0    1_1                          Что нового будет в марте?
# 1    1_2                   Когда приедет выставка Морозова?
# 2    1_3              Расскажи мне про Пятницы в Пушкинском
# 3    1_4                     Когда откроется выставка Тату?
# 4    1_5                          Цены на билеты Гейнсборо?
# 5    1_6                       Какие квесты есть для детей?
# 6    1_7          Какие концерты будут на следующей неделе?
# 7    1_8              На какую лекцию по искусству сходить?
# 8    1_9                     Что мне посмотреть в выходные?
# 9   1_10                   Какие выставки были в 2019 году?
# 10  1_11        Где скачать аудиогид по выставке Гейнсборо?
# 11  1_12                     Как записать ребенка в кружок?
# 12  1_13                    Как связан с Пушкинским Рихтер?
# 13  1_14        Хочу что-нибудь по импрессионистам, срочно.
# 14  1_15       На выставке Гейнсборо можно фотографировать?
# 15  1_16                   Участвует ли музей в Библионочи?
# 16  1_17                          Есть ли в музее лекторий?
# 17  1_18                      Где узнать расписание лекций?
# 18  1_19                         Есть ли лекции про Дюрера?
# 19  1_20  Когда снова привезут “Джоконду” Леонардо да Ви...
# 20   2_1           Когда в музее длинный / продленный день?
# 21   2_2                   До которого часа работают кассы?
# 22   2_3                   Что запрещено проносить в музей?
# 23   2_4                   Есть ли камеры хранения в музее?
# 24   2_5                Где в музее посмотреть золото Трои?
# 25   2_6                      Сколько зданий у Пушкинского?
# 26   2_7                 Можно ли прийти в музей с собакой?
# 27   2_8                          Что есть в музейном кафе?
# 28   2_9                          Где висят импрессионисты?
# 29  2_10                            Как пройти без очереди?
# 30  2_11                     Можно в музее фотографировать?
# 31  2_12                   Где припарковаться в Пушкинском?
# 32  2_13  Можно ли заказать копию понравившейся картины/...
# 33  2_14                          Когда закончится стройка?
# 34  2_15                   Сколько стоит карта Друга музея?
# 35  2_16                                      Где тут лифт?
# 36  2_17                        Экспозиция для слабовидящих
# 37  2_18                     Как доехать от метро до музея?
# 38  2_19                       Есть ли при Музее гостиница?
# 39  2_20                          Где кабинет Марины Лошак?
# 40   3_1                        Хочу найти все об орнаменте
# 41   3_2              Порекомендуй литературу по Ренессансу
# 42   3_3                    Дюрер, гравюры, что у вас есть?
# 43   3_4                              Нужны книги Бакштейна
# 44   3_5                    Список изданий ГМИИ за 2017 год
# 45   3_6               Что посмотреть по японской керамике?
# 46   3_7  Сколько в коллекции предметов раннего средневе...
# 47   3_8                              Каталог «Золота Трои»
# 48   3_9  Какие самые древние монеты есть в коллекции му...
# 49  3_10                       Мумии и саркофаги настоящие?
# 50  3_11                  Почему в музее так много слепков?
# 51  3_12       Покажите все предметы с изображением лошади.
# 52  3_13  Самые знаменитые картины в Пушкинском / шедевр...
# 53  3_14                     Что в музее есть из алебастра?
# 54  3_15          Покажите взорванные в Сирии крылатые Шеду
# 55  3_16                  У вас есть современное искусство?
# 56  3_17                         Где найти палитры Матисса?
# 57  3_18          Откуда в музее картина «Девочка на шаре»?
# 58  3_19         Есть ли в музее картины Леонардо да Винчи?
# 59  3_20                               Расскажи о «Давиде»?
#
#                                         lemmatization
# 0                               что новое быть в март
# 1                     когда приехать выставка морозов
# 2               рассказать я про пятница в пушкинский
# 3                        когда открыться выставка тат
# 4                             цена на билет гейнсборо
# 5                       какой квеста есть для ребёнок
# 6              какой концерт быть на следующий неделя
# 7                на какой лекция по искусство сходить
# 8                         что я посмотреть в выходной
# 9                      какой выставка быть в 2019 год
# 10         где скачать аудиогид по выставка гейнсборо
# 11                      как записать ребёнок в кружок
# 12                    как связать с пушкинский рихтер
# 13          хотеть что нибыть по импрессионист срочно
# 14        на выставка гейнсборо можно фотографировать
# 15                  участвовать ли музей в библионочь
# 16                           есть ли в музей лекторий
# 17                       где узнать расписание лекция
# 18                           есть ли лекция про дюрер
# 19  когда снова привезти “джоконду” леонардо да винчи
# 20                когда в музей длинный продлить день
# 21                      до который час работать касса
# 22                    что запретить проносить в музей
# 23                    есть ли камера хранение в музей
# 24               где в музей посмотреть золото троить
# 25                        сколько здание у пушкинский
# 26                   можно ли прийти в музей с собака
# 27                           что есть в музейный кафе
# 28                           где висеть импрессионист
# 29                             как пройти без очередь
# 30                      можно в музей фотографировать
# 31                    где припарковаться в пушкинский
# 32  можно ли заказать копия понравиться картина ск...
# 33                          когда закончиться стройка
# 34                    сколько стоить карта друг музей
# 35                                       где тут лифт
# 36                        экспозиция для слабовидящий
# 37                      как доехать от метро до музей
# 38                        есть ли при музей гостиница
# 39                           где кабинет марина лошак
# 40                       хотеть найти весь о орнамент
# 41            порекомендовать литература по ренессанс
# 42                        дюрер гравюра что у вы есть
# 43                              нужный книга бакштейн
# 44                    список издание гмия за 2017 год
# 45                 что посмотреть по японский керамик
# 46   сколько в коллекция предмет ранний средневековье
# 47                              каталог «золото трои»
# 48  какой самый древние монета есть в коллекция музей
# 49                         мумия и саркофаг настоящий
# 50                    почему в музей так много слепок
# 51         показать весь предмет с изображение лошадь
# 52  самый знаменитый картина в пушкинский шедевр п...
# 53                       что в музей есть из алебастр
# 54             показать взорвать в сирия крылатый шед
# 55                    у вы есть современный искусство
# 56                           где найти палитра матисс
# 57           откуда в музей картина «девочка на шаре»
# 58          есть ли в музей картина леонардо да винчи
# 59                              рассказать о «давиде»

# %%
dfq.to_csv("data/questions.csv", sep=';', index=False)
